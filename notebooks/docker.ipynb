# %%
import docker
import os

# %%
client = docker.from_env()

# %%
# https://docker-py.readthedocs.io/en/stable/containers.html
# https://docs.docker.com/engine/reference/run/
client.containers.run(image="tarsioonofrio/torch-serve-test",
                      command="torchserve --model-store=/home/model-server/model-store/ --models densenet161.mar",
                      remove=True, name="mar",
                      ports={8080:8080, 8081:8081, 7070:7070, 7071:7071},
    )
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-95f6b410868a> in <module>
#       2 # https://docs.docker.com/engine/reference/run/
#       3 volumes = {f"{os.getcwd()}/serve/examples": {'bind': "/home/model-server/examples", 'mode': 'ro'},}
# ----> 4 client.containers.run(image="tarsioonofrio/torch-serve-test",
#       5                       command="torchserve --model-store=/home/model-server/model-store/ --models densenet161.mar",
#       6                       remove=True, name="mar",
#
# ~/anaconda3/envs/torch-serve/lib/python3.8/site-packages/docker/models/containers.py in run(self, image, command, stdout, stderr, remove, **kwargs)
#     829             )
#     830
# --> 831         exit_status = container.wait()['StatusCode']
#     832         if exit_status != 0:
#     833             out = None
#
# ...
